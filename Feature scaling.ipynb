# %%
import numpy as np
import pandas as pd

# %%
stand_scaler = pd.DataFrame({'x1':np.random.normal(0,2,100),
                            'x2':np.random.normal(3,5,100),
                            'x3':np.random.normal(-2,2,100)})

# %%
stand_scaler
# Out:
#           x1         x2        x3
# 0  -0.745433  -1.933598  0.478648
# 1   0.481800  -0.038512 -2.955034
# 2   0.320215  10.894733  0.056236
# 3  -4.117661  12.511824 -1.763058
# 4  -4.858532  11.292724 -2.273245
# ..       ...        ...       ...
# 95 -2.691239   0.658920 -3.753337
# 96 -0.515117   5.078740 -3.531260
# 97 -1.452890  -0.375059 -1.601536
# 98  1.730731   5.130969 -3.530082
# 99 -1.137648   7.562822 -5.410256
#
# [100 rows x 3 columns]

# %%
stand_scaler.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
stand_sca = StandardScaler()

# %%
stand_scaler1 = stand_sca.fit_transform(stand_scaler)

# %%
stand_scaler1
# Out:
# array([[-3.36930340e-01, -1.03152089e+00,  1.39826600e+00],
#        [ 2.38721912e-01, -6.76011445e-01, -6.91897859e-01],
#        [ 1.62927986e-01,  1.37501472e+00,  1.14113371e+00],
#        [-1.91872507e+00,  1.67837355e+00,  3.36864448e-02],
#        [-2.26624161e+00,  1.44967596e+00, -2.76876788e-01],
#        [-1.22289430e+00, -9.42482798e-01,  3.77129345e+00],
#        [-9.65338628e-01, -2.21521658e-02, -1.07822342e+00],
#        [ 1.27693385e+00,  1.32856174e+00,  1.44249474e+00],
#        [-2.02253563e-01, -1.34765560e+00, -6.87137790e-01],
#        [-1.68459420e+00,  1.48103872e+00, -7.59723571e-01],
#        [-4.20707459e-01, -2.35661579e-01, -1.13904728e+00],
#        [-5.31714273e-03, -1.11124725e-01, -9.33768656e-01],
#        [ 2.32574639e-01, -1.58263060e+00,  2.43517850e-01],
#        [ 1.44322896e-01,  3.61493297e-01,  1.63690437e+00],
#        [-1.02872733e+00, -5.11648828e-01,  9.28323486e-01],
#        [ 4.60133306e-01,  1.87980701e-02, -9.63516339e-01],
# ...

# %%
stand_scaler2 = pd.DataFrame(stand_scaler1,columns=['x1','x2','x3'])

# %%
stand_scaler2
# Out:
#           x1        x2        x3
# 0  -0.336930 -1.031521  1.398266
# 1   0.238722 -0.676011 -0.691898
# 2   0.162928  1.375015  1.141134
# 3  -1.918725  1.678374  0.033686
# 4  -2.266242  1.449676 -0.276877
# ..       ...       ...       ...
# 95 -1.249640 -0.545177 -1.177843
# 96 -0.228897  0.283961 -1.042660
# 97 -0.668774 -0.739146  0.132008
# 98  0.824552  0.293759 -1.041943
# 99 -0.520905  0.749964 -2.186450
#
# [100 rows x 3 columns]

# %%
stand_scaler2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Outlayer Scaling

# %%
outlier_df = pd.DataFrame({
    'x1':np.concatenate([np.random.normal(20,1,1000),np.random.normal(1,1,25)]),
    'x2':np.concatenate([np.random.normal(30,1,1000),np.random.normal(50,1,25)]),
    })

# %%
outlier_df
# Out:
#              x1         x2
# 0     20.425933  30.120872
# 1     18.375198  32.424669
# 2     21.321434  29.798773
# 3     19.792346  29.010521
# 4     19.042013  30.379536
# ...         ...        ...
# 1020   1.633587  50.834868
# 1021   0.727598  49.192411
# 1022   1.051148  51.662781
# 1023  -0.351717  50.551116
# 1024   1.352285  50.627137
#
# [1025 rows x 2 columns]

# %%
outlier_df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs = RobustScaler()

# %%
outlier_df1 = rs.fit_transform(outlier_df)

# %%
outlier_df2 = pd.DataFrame(outlier_df1,columns=['x1','x2'])

# %%
outlier_df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
